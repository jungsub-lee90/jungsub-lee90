# %% [markdown]
# ## tensorflow stable diffusion 찍먹

# %%
#!pip install --upgrade keras-cv
# Out:
# Requirement already satisfied: keras-cv in c:\users\user\anaconda3_\lib\site-packages (0.3.4)
# Requirement already satisfied: packaging in c:\users\user\anaconda3_\lib\site-packages (from keras-cv) (21.3)
# Requirement already satisfied: regex in c:\users\user\anaconda3_\lib\site-packages (from keras-cv) (2022.7.9)
# Requirement already satisfied: absl-py in c:\users\user\anaconda3_\lib\site-packages (from keras-cv) (1.3.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3_\lib\site-packages (from packaging->keras-cv) (3.0.9)

# %%
#!pip install --upgrade tensorflow

# %%
#!pip install --upgrade tensorflow_datasets

# %%
import time
from tensorflow import keras
import keras_cv
import matplotlib.pyplot as plt
from translate import Translator

# %%
model = keras_cv.models.StableDiffusion(img_width=512 , img_height=512, jit_compile=True)
# Out:
# By using this model checkpoint, you acknowledge that its usage is subject to the terms of the CreativeML Open RAIL-M license at https://raw.githubusercontent.com/CompVis/stable-diffusion/main/LICENSE

# %%
translator= Translator(from_lang='ko', to_lang= 'en')
translation = translator.translate('금천구에 땅 사러온 미키마우스')
print(translation)
# Out:
# Mickey Mouse came to buy land in the Geumcheon District.

# %%
def plot_images(images):
    plt.figure(figsize=(10,10))
    for i in range(len(images)):
        ax = plt.subplot(1,len(images), i +1)
        plt.imshow(images[i])
        plt.axis('off')
        plt.tight_layout()

# %%
images= model.text_to_image(translation, batch_size=3)
plot_images(images)
# Out:
# 25/25 [==============================] - 524s 19s/step
